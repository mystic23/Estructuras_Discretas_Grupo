# %% [markdown]
# <a href="https://colab.research.google.com/github/mystic23/Estructuras_Discretas_Grupo/blob/main/practica_junior_advance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2, numpy as np,matplotlib.pyplot as plt
T=cv2.imread("/content/drive/MyDrive/Colab Notebooks/Fotos/escudo junior.png");plt.imshow(T)
filas,columnas,capas = T.shape;print(T.shape)
b=int(input("digita grosor de la linea. b="))
T[filas//2-b:filas//2+b,:,:]=0
T[:,columnas//2-b:columnas//2+b,:]=0;plt.imshow(T)
for f in range(filas): T[f,f,:]=0;
for f in range(filas): T[f, np.abs(filas-columnas)-f,:]=4;
plt.imshow(T)
# Out:
# (1200, 1200, 3)
# digita grosor de la linea. b=10

# %% [markdown]
# ##1.) Se Lanzan $n$ dados $T=10^i$ veces. $i=1, 2, 3$.
# Muestre los 3 gráficos de barras correspondientes.

# %%
import numpy as np
# n = 5

# dados = np.zeros(5*n+1)
# for i in range(n):
#   entonces = dados(np.sum(np.random.randint(1,6+1,n)-n)) += 1

# print(entonces)

# a = np.linspace(n, 6 * n, 5 * n + 1)
# random = np.random.randint(1,6+1,n)
# dato = np.sum(random)

# for i in range(random.len()):
# print(dados)
# print(random)
# print(dato)
# import numpy as np

# n = 5

# dados = np.zeros(5 * n + 1)
# for i in range(n):
#     random = np.linspace(n, 6 * n, 5 * n + 1)
#     total = np.sum(random) - n
#     dados[total] += 1

# print(dados)

import numpy as np

n = 5
num_simulations = 10000  # Number of simulations

dados = np.zeros(5 * n + 1)
for _ in range(num_simulations):
    outcomes = np.random.randint(1, 7, n)
    total = np.sum(outcomes)
    dados[total] += 1

print(dados)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-5b0d6a8866c0> in <cell line: 36>()
#      37     outcomes = np.random.randint(1, 7, n)
#      38     total = np.sum(outcomes)
# ---> 39     dados[total] += 1
#      40
#      41 print(dados)
#
# IndexError: index 26 is out of bounds for axis 0 with size 26

# %%
import numpy as np, matplotlib.pyplot as plt

def ndados(n,T):
  for l in range(T):
    results[np.sum(np.random.randint(1, 6+1, n))-n]+=1
  fig, ax = plt.subplots()
  ax.set(ylabel='Frecuencia absoluta', xlabel=f'Suma de los puntos en ')
  h=ax.bar(np.arange(1,5*n+2,1), results)
  ax.bar_label(h)
  plt.show()

T= int(input('Ingrese el número de lanzamientos, T = ')); n= int(input('Ingrese el número de dados, n = '))
results=np.zeros(5*n+1)
ndados(n,T)
# Out:
# Ingrese el número de lanzamientos, T = 1000
# Ingrese el número de dados, n = 5

# %%
#Jacobsthal, Esto es para resolver con fracciones parciales
import sympy as sp
z=sp.symbols("z")
FGO=1/(1-z-2*z**2)
print(sp.apart(FGO))
# Out:
# -2/(3*(2*z - 1)) + 1/(3*(z + 1))
